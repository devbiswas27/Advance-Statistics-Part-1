# %% [markdown]
# #Statistics Advance part 1

# %% [markdown]
# Q1.What is a random variable in probability theory?
#
# A random variable is a function that maps outcomes of a random experiment to numerical values.
#
# 🔑 Key Concepts:
# A random variable does not mean "random number" — it's a rule or function that assigns numbers to outcomes.
#
# There are two main types:
#
# 1. Discrete Random Variable
# Takes on countable values (like integers)
#
# Example:
# Let X be the number of heads in 3 coin tosses. Possible values:
# {0,1,2,3}
#
# 2. Continuous Random Variable
# Takes on uncountably infinite values (like any real number in a range)
#
# Example:
#
# Let Y be the time (in seconds) it takes for a website to load.
#
# Y could be 1.5, 1.52, 1.523..., etc.
#
# 📈 How Random Variables Are Used
#
# They allow us to define probability distributions (e.g. Binomial, Normal, Poisson)
#
# Let you compute things like:
#
# Expected value (mean)
#
# Variance
#
# Probability of events, like
# P(X≥2)

# %% [markdown]
# Q2.What are the types of random variables?
#
# In probability theory, random variables are classified primarily into two types based on the nature of their possible values:
#
# 🔹 1. Discrete Random Variable
#
# A discrete random variable takes on countable values — either finite or countably infinite.
#
#  Characteristics:
#
# Values can be listed (e.g., 0, 1, 2, 3, …)
#
# Has a Probability Mass Function (PMF)
#
# Total probability across all values = 1
#
#  Examples:
#
# Number of heads in 10 coin tosses
#
# Number of emails received in an hour
#
# Rolling a die:
#
# X∈{1,2,3,4,5,6}
#
# 🔹 2. Continuous Random Variable
#
# A continuous random variable takes values from an uncountable range, typically any real number within an interval.
#
# Characteristics:
#
# Values lie on a continuum (e.g., height, time, weight)
#
# Described using a Probability Density Function (PDF)
#
# Probability at a single point is zero:
#
# P(X=x)=0
#
# You calculate probabilities over intervals, like
#
# P(a≤X≤b)
#
# 📌 Examples:
#
# Time taken to finish an exam
#
# Temperature on a given day
#
# Height of a person
#
# 🔸 Other Classifications (Advanced/Contextual)
#
#     Type	                                   Description
#     Mixed Random Variable	       Has both discrete and continuous parts (e.g., a model that includes fixed spikes and a smooth distribution)
#     Multivariate Random Variable	A vector of two or more random variables (e.g., joint distribution of height and weight)
#     Indicator Variable	        A binary variable that takes 0 or 1 depending on whether an event occurs (used in probability and statistics)

# %% [markdown]
# Q3.What is the difference between discrete and continuous distributions?
#
# The difference between discrete and continuous distributions lies in the type of values the random variable can take, and how probabilities are assigned.
#
# 🔹 Discrete Distribution
#
# A discrete distribution describes the probability of outcomes of a discrete random variable — one that takes countable values.
#
# ✅ Key Features:
#
# Probabilities are assigned to individual values
#
# Described by a Probability Mass Function (PMF):
#
# P(X=x)
# Total probability over all possible values = 1
#
#  Examples:
#
# Binomial Distribution: Number of successes in
# 𝑛
#  Bernoulli trials
#
# Poisson Distribution: Number of events in a fixed time interval
#
# Geometric Distribution: Number of trials until first success
#
# 🔸 Example of a Discrete Distribution:
#
# Rolling a 6-sided die:
#
#
# P(X=1)=P(X=2)=⋯=P(X=6)=
# 1/6
#
# 🔹 Continuous Distribution
#
# A continuous distribution applies to continuous random variables, which can take uncountably infinite values (usually any value in an interval).
#
# ✅ Key Features:
#
# Probabilities are assigned over intervals, not individual values
#
# Described by a Probability Density Function (PDF):
#
# P(a≤X≤b)=∫
# a
# b
# ​
#  f(x)dx
#
# P(X=x)=0 for any specific value
# 𝑥
#
#
# 📌 Examples:
#
# Normal Distribution: Bell curve for heights, test scores, etc.
#
# Exponential Distribution: Time between events in a Poisson process
#
# Uniform Distribution (continuous): Equal likelihood over an interval
#
# 🔸 Example of a Continuous Distribution:
# Time (in seconds) to load a webpage, modeled by a Normal distribution:
#
#
# P(1.5≤X≤2.5)=∫
# 1.5
# 2.5
# ​
#  f(x)dx

# %% [markdown]
# Q4.What are probability distribution functions (PDF)?
#
# In probability theory, a Probability Distribution Function (often abbreviated as PDF) is a function that describes the likelihood of a continuous random variable taking on a range of values.
#
# 🔹 Key Features of a PDF:
# A PDF gives probability density, not actual probability at a point.
#
# For a continuous random variable
# 𝑋
# , the probability that X falls within an interval
# [a,b] is:
# P(a≤X≤b)=∫
# a
# b
# ​
#  f(x)dx
#
#  where
# f(x) is the PDF.

# %% [markdown]
# Q5.  How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)
#
# | Feature          | PDF (Probability Density Function)                 | CDF (Cumulative Distribution Function)          |
# | ---------------- | ------------------------------------------------------- | --------------------------------------------------- |
# | Applicable to    | **Continuous random variables** (also PMF for discrete) | Both **discrete and continuous** random variables   |
# | Describes        | Probability **density** at a point                      | Cumulative probability **up to a point**            |
# | Definition       | $f(x)$: Shape of the distribution                       | $F(x) = P(X \leq x)$: Area under the PDF curve      |
# | Value at a point | $P(X = x) = 0$ (for continuous)                         | $F(x) = \int_{-\infty}^{x} f(t)\,dt$                |
# | Range of values  | $f(x) \geq 0$, area under curve = 1                     | $0 \leq F(x) \leq 1$, non-decreasing function       |
# | Interpretation   | How likely values are **near** $x$                      | How likely values are **less than or equal to** $x$ |
# | Example output   | Height at a specific point                              | Probability height is ≤ that point                  |
# | Visualization    | Bell curve (e.g., normal distribution)                  | S-shaped curve (e.g., logistic or normal CDF)       |

# %% [markdown]
# Q.6.What is a discrete uniform distribution?
#
# A discrete uniform distribution is a probability distribution where a finite number of outcomes are equally likely.
#
# 🔹 Definition:
# If a random variable
# 𝑋
#  can take on
# 𝑛
#  distinct values
# 𝑥
# 1
# ,
# 𝑥
# 2
# ,
# …
# ,
# 𝑥
# 𝑛
# , each with equal probability, then:
#
# 𝑃
# (
# 𝑋
# =
# 𝑥
# 𝑖
# )
# =
# 1
# 𝑛
# ,for i=1,2,...,n
#
# Key Characteristics
#
#
# | Feature              | Description                                              |
# | -------------------- | -------------------------------------------------------- |
# | Type                 | **Discrete**                                             |
# | Values               | Finite and countable                                     |
# | Probabilities        | All outcomes have equal probability                      |
# | Probability function | $P(X = x) = \frac{1}{b - a + 1}$ where $a \leq x \leq b$ |
# | Mean                 | $\mu = \frac{a + b}{2}$                                  |
# | Variance             | $\sigma^2 = \frac{(b - a + 1)^2 - 1}{12}$                |

# %% [markdown]
# Q7.What are the key properties of a Bernoulli distribution?
#
# The Bernoulli distribution is one of the most fundamental distributions in probability and statistics, modeling situations with only two outcomes — like flipping a coin, success/failure, yes/no, etc.
#
#  Definition:
#
# A Bernoulli distribution is a discrete distribution where a random variable
# 𝑋
#  takes the value:
# pey properties
#
# | Property                  | Description                                       |
# | ------------------------- | ------------------------------------------------- |
# | **Type**                  | Discrete                                          |
# | **Possible Values**       | $X \in \{0, 1\}$                                  |
# | **Parameter**             | $p \in [0, 1]$, the probability of success        |
# | **Mean (Expected Value)** | $\mu = p$                                         |
# | **Variance**              | $\sigma^2 = p(1 - p)$                             |
# | **Mode**                  | 0 if $p < 0.5$; 1 if $p > 0.5$; both if $p = 0.5$ |
# | **Skewness**              | $\frac{1 - 2p}{\sqrt{p(1 - p)}}$                  |
# | **Kurtosis**              | $\frac{1 - 6p(1 - p)}{p(1 - p)}$                  |

# %% [markdown]
# Q8.What is the binomial distribution, and how is it used in probability?
#
# The binomial distribution is a discrete probability distribution that models the number of successes in a fixed number of independent trials, where each trial has only two possible outcomes: success or failure.
#
# 🔹 Real-World Analogy:
#
# Imagine flipping a coin 10 times and counting how many times it lands on heads. That’s a binomial scenario.
#
# Key Components:
# Let
# X∼Binomial(n,p), where:
#
# 𝑛
# : number of trials
#
# 𝑝
# : probability of success in a single trial
#
# 𝑋
# : number of successes in
# 𝑛
#  trials
#
#  Assumptions:
#
# Fixed number of trials
# 𝑛
#
#
# Each trial is independent
#
# Two outcomes per trial: success or failure
#
# Probability of success
# 𝑝
#  is constant for all trials

# %% [markdown]
# Q9. What is the Poisson distribution and where is it applied?
#
# The Poisson distribution is a discrete probability distribution that models the number of events occurring in a fixed interval of time or space, under the following conditions:
#
# Events occur independently
#
# Events occur at a constant average rate
#
# Two events cannot occur simultaneously
#
#  Common Use Cases:
#
# The Poisson distribution is used when you're counting rare, random events over time or space. Examples:
#
# Number of customer arrivals at a bank per hour
#
# Number of emails received in a day
#
# Number of typos per page in a book
#
# Number of phone calls to a help desk per minute
#
# Number of decay events per second from a radioactive source

# %% [markdown]
# Q10.What is a continuous uniform distribution?
#
# If a continuous random variable
# 𝑋
#  is uniformly distributed between two values
# 𝑎
#  and
# 𝑏
# , then:
#
# X∼U(a,b)
#
# This means that:
#
# 𝑋
#  can take any real value in the interval
# [a,b]
#
# The probability density is constant across the interval
#
# Real-Life Examples:
# Spinning a roulette wheel and landing anywhere between 0 and 1
#
# Picking a random real number between 5 and 10
#
# Measuring random delays between fixed limits (e.g., 1–3 seconds)

# %% [markdown]
# Q11.What are the characteristics of a normal distribution?
#
# The normal distribution, also known as the Gaussian distribution, is one of the most important and widely used distributions in statistics and data science. It models many natural phenomena due to the Central Limit Theorem.
#
#      Characteristics of a Normal Distribution
#
#     Characteristic	                     Description
#     Shape	                        Symmetrical, bell-shaped curve
#     Mean = Median = Mode         	All are equal at the center
#     Tails	                       Extend infinitely in both directions but never touch the x-axis
#     Defined by	                Two parameters: mean  𝜇 and standard deviation  𝜎
#
#     Area under curve          	Total area = 1 (i.e., represents total probability)
#     Empirical Rule (68-95-99.7)	 About 68% of data is within 1σ, 95% within 2σ, and 99.7% within 3σ of the mean

# %% [markdown]
# Q12.What is the standard normal distribution, and why is it important?
#
# The standard normal distribution is a special case of the normal distribution with:
#
# Mean μ=0
#
# Standard deviation σ=1
#
# It’s denoted as:
#
# Z∼N(0,1)
#
# Here, the random variable is often called Z, and its values are referred to as Z-scores.
#
#  1. Simplifies Calculations
#
# By converting any normal variable to a standard normal variable, you can use Z-tables or functions like norm.cdf() in Python to calculate probabilities.
#
# 2. Z-Score Transformation
#
# Any normally distributed variable
# X∼N(μ,σ
# 2
#  ) can be converted into a standard normal variable
# 𝑍 using:
#
# 𝑍
# =
# 𝑋
# −
# 𝜇/
# 𝜎
#
#
# 3. Used in Statistical Tests
#
# Common tests (Z-tests, confidence intervals, hypothesis testing) rely on standard normal values for calculating critical values.
#
#  4. Universality via Central Limit Theorem
#
# Many sample means become approximately standard normally distributed as sample size increases, even if the original data isn’t normal.

# %% [markdown]
# Q13.= What is the Central Limit Theorem (CLT), and why is it critical in statistics?
#
# The Central Limit Theorem (CLT) is one of the most fundamental and powerful concepts in statistics. It explains why many statistical methods work—even when the data aren't normally distributed.
#
# If you take a large number of random samples from any population (with a finite mean
# 𝜇
# and standard deviation
# 𝜎
# ), then the sampling distribution of the sample mean will approach a normal distribution as the sample size increases—regardless of the shape of the original population.
#
# Why CLT is important:
#
# | Reason                                                         | Explanation                                                                                      |
# | -------------------------------------------------------------- | ------------------------------------------------------------------------------------------------ |
# | Enables normal approximation                             | You can treat sample means as normally distributed, even if the data itself isn’t.               |
# |  **Foundation for confidence intervals & hypothesis testing** | Most classical inference methods (Z-tests, t-tests) depend on the CLT.                           |
# |  **Used in quality control, economics, science**              | Any field involving data benefits from the CLT for estimating averages and modeling uncertainty. |
# |  **Allows prediction & modeling**                             | Helps us model real-world randomness and uncertainty reliably.                                   |

# %% [markdown]
# Q14.How does the Central Limit Theorem relate to the normal distribution?
#
# The Central Limit Theorem (CLT) is deeply connected to the normal distribution and is the reason why the normal distribution is so important and widely used in statistics.
#
#  How CLT Relates to the Normal Distribution:
#
# 🔹 1. CLT Explains the Origin of the Normal Distribution in Sampling
# The CLT states that regardless of the original distribution of a population, the distribution of sample means will approach a normal distribution as the sample size increases.
#
# So, even if your original data is:
#
# skewed
#
# uniform
#
# exponential
#
# weird-looking
#
#  The distribution of the averages (means) from repeated samples will be approximately normal (bell-shaped), especially for sample sizes
#
# n≥30.
#
# 🔹 2. Enables Use of Normal Distribution in Real-World Problems
# Because of the CLT:
#
# You can assume normality when analyzing sample means, even if the original data isn’t normal.
#
# This justifies using Z-scores, confidence intervals, and hypothesis tests based on the normal distribution.
#
# 🔹 3. Standard Normal Distribution Is the CLT’s Limit Case

# %% [markdown]
# Q15.What is the application of Z statistics in hypothesis testing?
#
# Z-statistics (or Z-scores) play a central role in hypothesis testing when dealing with normally distributed data or large sample sizes. The Z-statistic tells you how far your sample statistic is from the null hypothesis value, in terms of standard deviations.
#
# Steps in Hypothesis Testing Using Z-Statistics
#
# ✅ Step 1: State Hypotheses
#
# Null hypothesis (
# 𝐻
# 0
#  ): No effect or difference (e.g.,
# μ=100)
#
# Alternative hypothesis (
# 𝐻
# 1
# ): There is an effect (e.g.,
# 𝜇
# ≠
# 100)
#
#
# ✅ Step 2: Choose Significance Level
# Common choices: α=0.05,0.01
#
# ✅ Step 3: Calculate Z-statistic
# Use the formula above.
#
# ✅ Step 4: Determine Critical Z-value
# For
#
# α=0.05, two-tailed test:
# Z
# critical
# ​
#  =±1.96
#
# ✅ Step 5: Make a Decision
# If
#
# ∣Z∣>Z
# critical
#
#  : Reject
# 𝐻
# 0
#
#
#
# Else: Fail to reject
# 𝐻
# 0
#
#
#  When to use Z test:
#
#  | Scenario                 | Use Z-test if:                                  |
# | ------------------------ | ----------------------------------------------- |
# | **One-sample mean test** | Population standard deviation $\sigma$ is known |
# | **Two-sample mean test** | Large samples and known variances               |
# | **Proportion tests**     | Large sample sizes ($np \ge 5, n(1-p) \ge 5$)   |
#
#
# Real-World Applications
#
# Quality control: Is the average defect rate higher than expected?
#
# A/B testing: Is version A performing better than version B?
#
# Medical trials: Is the drug's average effect different from placebo?
#
# Survey analysis: Is a sample mean significantly different from the claimed value?

# %% [markdown]
# Q16. How do you calculate a Z-score, and what does it represent?
#
# A Z-score (also called a standard score) tells you how far a data point is from the mean, measured in standard deviations.
#
# Formula for Z-Score:
# 𝑍
# =
# 𝑋
# −
# 𝜇/
# 𝜎
#
#
# Where:
#
#
# X = the data point (observation)
#
#
# μ = the mean of the distribution
#
#
# σ = the standard deviation of the distribution
#
# What the Z score represent
#
# | Z-score  | Interpretation                       |
# | -------- | ------------------------------------ |
# | $Z = 0$  | Data point is **at the mean**        |
# | $Z > 0$  | Data point is **above the mean**     |
# | $Z < 0$  | Data point is **below the mean**     |
# | $Z = 2$  | 2 standard deviations above the mean |
# | $Z = -3$ | 3 standard deviations below the mean |
#
# Why Z-Scores Are Useful:
#
# Standardizes data for comparison across different units
#
# Used in normal distribution probability calculations
#
# Essential in Z-tests, outlier detection, and grading scales
#
# Makes data comparable even if from different datasets

# %% [markdown]
# Q17.What are point estimates and interval estimates in statistics?
#
# Both point estimates and interval estimates are used to infer population parameters (like the mean, proportion, or standard deviation) based on sample data.
#
#  1. Point Estimate
#
# A point estimate is a single value used to estimate a population parameter.
#
# | Parameter                     | Point Estimate              |
# | ----------------------------- | --------------------------- |
# | Population Mean $\mu$         | Sample Mean $\bar{x}$       |
# | Population Proportion $p$     | Sample Proportion $\hat{p}$ |
# | Population Std. Dev. $\sigma$ | Sample Std. Dev. $s$        |
#
# Interval Estimate
# An interval estimate gives a range of values, within which the population parameter is expected to lie, along with a confidence level.
#
# ✅ Example:
# A 95% confidence interval for the mean might be:
#
# 𝑥
# ˉ
# ±
# 1.96
# ×
# 𝑠/
# 𝑛
#
#   Interpretation: “We are 95% confident the population mean lies within this interval.”

# %% [markdown]
# Q18.What is the significance of confidence intervals in statistical analysis?
#
# A confidence interval (CI) is a range of values used to estimate a population parameter (like a mean or proportion), with an associated level of confidence (like 95%). It adds context and reliability to point estimates, making it a core tool in inferential statistics.
#
#  Why Confidence Intervals Matter:
#
#  1. Quantifies Uncertainty
#
# A point estimate (e.g., sample mean) gives one value — but a confidence interval shows how much uncertainty is in that estimate.
#
# It answers: “How precise is our estimate?”
#
#  2. Provides a Range for the True Parameter
#
# A 95% CI means: “We are 95% confident that the true population value lies within this range.”
#
# It does not mean there's a 95% chance the true value is in the interval — the interval either does or doesn't contain it; the 95% refers to the method's reliability over many samples.
#
#  3. Supports Decision Making
#
# Wider intervals → more uncertainty
#
# Narrower intervals → more precise estimate
# Helps you decide whether a treatment effect, business outcome, or policy impact is statistically meaningful.
#
#  4. Preferred Over P-values Alone
#
# Confidence intervals show the effect size and its range, while a p-value just tells you whether something is statistically significant.
#
# Example: A p-value might say “significant,” but a CI shows how large or small the effect might actually be.
#
#  5. Used in Hypothesis Testin
# If the null hypothesis value (e.g.
# μ=0) falls outside the confidence interval, you can often conclude that the result is statistically significant at the chosen level (like 5%).

# %% [markdown]
# Q19.What is the relationship between a Z-score and a confidence interval?
#
# The Z-score and the confidence interval (CI) are tightly connected in statistics. The Z-score is used to calculate confidence intervals when the population standard deviation is known or the sample size is large.
#
# How Z-Score Controls the Width of the CI
# Higher Z-score → Wider interval → More confidence
#
# Lower Z-score → Narrower interval → Less confidence
#
# Example:
# A 99% confidence interval (Z = 2.576) will be wider than a 90% interval (Z = 1.645) because you need to "capture" more of the distribution.
#
# Z-scores help define the margin of error: The larger the Z, the more “cautious” the estimate.
#
# You use the Z-table (standard normal table) to find the Z-value for your confidence level.
#
# In hypothesis testing, if the Z-statistic of your sample lies outside the CI bounds, it's considered statistically significant.

# %% [markdown]
# Q20.How are Z-scores used to compare different distributions?
#
# Z-scores are a powerful way to compare values from different distributions, even when those distributions have different means and standard deviations. They work by standardizing values — converting them into a common scale: the standard normal distribution.
#
# Compairing accross units and scales
#
# | Context                                       | Use of Z-score                                      |
# | --------------------------------------------- | --------------------------------------------------- |
# | Comparing exam scores from different subjects | Normalize scores to judge relative performance      |
# | Health metrics like weight and height         | Compare to population averages, regardless of units |
# | Finance (returns, risk)                       | Compare performance or volatility across assets     |

# %% [markdown]
# Q21.What are the assumptions for applying the Central Limit Theorem?
#
# The Central Limit Theorem (CLT) states that the sampling distribution of the sample mean will tend to follow a normal distribution as the sample size increases — regardless of the original population distribution — under certain assumptions.
#
#  Core Assumptions of CLT:
#
# 1. Independent Observations
#
# Each data point in the sample should be independent of the others.
#
# Example: No repeated measures or paired data unless properly accounted for.
#
# 🔸 If data are dependent (e.g., time series or clustered samples), the CLT may not hold without adjustments.
#
# 2. Identically Distributed Random Variables
#
# All samples must come from the same population with the same distribution.
#
# The population must have a finite mean (μ) and finite variance (σ²).
#
# 3. Sample Size Should Be Sufficiently Large
#
# Rule of thumb:
# n≥30
#
# For highly skewed or non-normal populations, a larger sample size may be required for the sampling distribution to approximate normality.
#
# For normal populations, the sample mean is normally distributed even for small
# 𝑛
#
#
# 4. Finite Mean and Variance
#
# The CLT requires that the population has:
#
# A defined (finite) mean
# 𝜇
#
#
# A defined (finite) variance
# 𝜎
# 2

# %% [markdown]
# Q22.What is the concept of expected value in a probability distribution?
#
# The expected value (EV), also known as the mean of a probability distribution, is a measure of the long-term average outcome of a random variable if the experiment were repeated many times.
#
# It tells you what value you can expect on average, even if the actual result varies each time.
#
# Why Expected Value Matters:
#
#     Use Case	                   Role of Expected Value
#     Games of chance	            Average win/loss per play
#     Insurance & risk management	Forecast expected payouts
#     Economics & finance       	Expected return on investment
#     Machine learning	          Used in loss functions and predictions

# %% [markdown]
# Q23.How does a probability distribution relate to the expected outcome of a random variable?
#
# A probability distribution describes how likely each possible value of a random variable is. The expected outcome—also called the expected value—is the weighted average of all those values, using their probabilities as weights.
#
#  Relationship in Simple Terms:
#
# The probability distribution tells you what could happen and how likely each outcome is.
#
# The expected value tells you what you should expect on average if you repeat the random process many times.
#
# Why It Matters:
#
#     Concept	                           Role of the Probability Distribution
#     Shape of distribution	         Determines how outcomes are spread
#     Probability weights	          Directly influence the expected value
#     Skewed distributions	        Shift the expected value away from the center
#     Symmetric distributions	      Mean and expected value often align
#
# Summary:
#
# A probability distribution is the full picture of outcomes and their likelihoods.
#
# The expected value is a single number summarizing the average outcome.
#
# The distribution’s shape and probabilities directly determine the expected outcome.
